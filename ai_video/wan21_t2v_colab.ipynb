# %% [markdown]
# # Wan 2.1 T2V 1.3B — 8-second ComfyUI demo
# Select a GPU runtime, then run the cells top-to-bottom.

# %%
# !git clone --depth 1 https://github.com/vireonis/vireonis.github.io.git /content/vireonis
# %cd /content/vireonis/ai_video
# !pip -q install requests ipywidgets

# %%
import subprocess
print(subprocess.check_output(['nvidia-smi','--query-gpu=name,memory.total','--format=csv,noheader']).decode())

# %%
from launch_colab import install, start
install()
start()

# %%
from app import *
